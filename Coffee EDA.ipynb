# %% [markdown]
# Dataset used:
#     https://www.kaggle.com/datasets/fatihb/coffee-quality-data-cqi?rvi=1

# %% [markdown]
# ### About Dataset
#
# #### Coffee Quality Institute
#
# The Coffee Quality Institute (CQI) is a non-profit organization that works to improve the quality and value of coffee worldwide. It was founded in 1996 and has its headquarters in California, USA.
#
# CQI's mission is to promote coffee quality through a range of activities that include research, training, and certification programs. The organization works with coffee growers, processors, roasters, and other stakeholders to improve coffee quality standards, promote sustainability, and support the development of the specialty coffee industry.
#
# #### Data
#
# CQI maintains a web database that serves as a resource for coffee professionals and enthusiasts who are interested in learning about coffee quality and sustainability. The database includes a range of information on coffee production, processing, and sensory evaluation. It also contains data on coffee genetics, soil types, and other factors that can affect coffee quality.
#
# #### Sensory evaluations (coffee quality scores)
#
# * Aroma: Refers to the scent or fragrance of the coffee.
# * Flavor: The flavor of coffee is evaluated based on the taste, including any sweetness, bitterness, acidity, and other flavor notes.
# * Aftertaste: Refers to the lingering taste that remains in the mouth after swallowing the coffee.
# * Acidity: Acidity in coffee refers to the brightness or liveliness of the taste.
# * Body: The body of coffee refers to the thickness or viscosity of the coffee in the mouth.
# * Balance: Balance refers to how well the different flavor components of the coffee work together.
# * Uniformity: Uniformity refers to the consistency of the coffee from cup to cup.
# * Clean Cup: A clean cup refers to a coffee that is free of any off-flavors or defects, such as sourness, mustiness, or staleness.
# * Sweetness: It can be described as caramel-like, fruity, or floral, and is a desirable quality in coffee.

# %% [markdown]
# # Objective
#
#    ##  To find the relationship between Flavor of coffee and Altitude where the coffee beans are produced.

# %% [markdown]
# ### Though there are many other important aspects that affects the quality of coffee beans, in this analysis we will find out how the altitude affects the flavor of coffee

# %% [markdown]
# ## Snapshot

# %% [markdown]
# ![Snapshot](DatasetPic.png)

# %% [markdown]
# ### Library

# %%
# importing numpy pandas mathplotand other methods
import pandas as pd             # data manipulation
import numpy as np              # perform mathmatical operations 
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline
import seaborn as sns           # for data visualization

# %%
#first read the data file
df= pd.read_csv('df_arabica_clean.csv')

# %%
# Complete information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             207 non-null    int64
#  1   ID                     207 non-null    int64
#  2   Country of Origin      207 non-null    object
#  3   Farm Name              205 non-null    object
#  4   Lot Number             206 non-null    object
#  5   Mill                   204 non-null    object
#  6   ICO Number             75 non-null     object
#  7   Company                207 non-null    object
#  8   Altitude               206 non-null    object
#  9   Region                 205 non-null    object
#  10  Producer               206 non-null    object
#  11  Number of Bags         207 non-null    int64
#  12  Bag Weight             207 non-null    object
#  13  In-Country Partner     207 non-null    object
# ...

# %% [markdown]
# From the above info we can find that:
#    * The entries in this dataset ranges from 0 to 207.
#    * There are total of 41 columns.
#    * The data types included are float, integer and object.
#    * Object means anything other than numerical value.
#    * Its memory usage is 66.4+ KB
#    * Those that dont have 207 are the missing values.
#    * Non-null means that something is there. In this case Company : has 207 nun-null values.

# %%
# quick look to dataset
df.head(207)
# Out:
#      Unnamed: 0   ID Country of Origin                             Farm Name  \
# 0             0    0          Colombia                      Finca El Paraiso
# 1             1    1            Taiwan              Royal Bean Geisha Estate
# 2             2    2              Laos                    OKLAO coffee farms
# 3             3    3        Costa Rica                             La Cumbre
# 4             4    4          Colombia                       Finca Santuario
# ..          ...  ...               ...                                   ...
# 202         202  202            Brazil                     Fazenda Conquista
# 203         203  203         Nicaragua                      Finca San Felipe
# 204         204  204              Laos                                     -
# 205         205  205       El Salvador  Rosario de Maria II, Area de La Pila
# 206         206  206            Brazil                         Walter Matter
#
# ...

# %%
# quick look to dataset from bottom
df.tail(207)
# Out:
#      Unnamed: 0   ID Country of Origin                             Farm Name  \
# 0             0    0          Colombia                      Finca El Paraiso
# 1             1    1            Taiwan              Royal Bean Geisha Estate
# 2             2    2              Laos                    OKLAO coffee farms
# 3             3    3        Costa Rica                             La Cumbre
# 4             4    4          Colombia                       Finca Santuario
# ..          ...  ...               ...                                   ...
# 202         202  202            Brazil                     Fazenda Conquista
# 203         203  203         Nicaragua                      Finca San Felipe
# 204         204  204              Laos                                     -
# 205         205  205       El Salvador  Rosario de Maria II, Area de La Pila
# 206         206  206            Brazil                         Walter Matter
#
# ...

# %%
print(len(df)) # number of rows
# Out:
# 207

# %%
print(len(df.columns))   # number of columns
# Out:
# 41

# %%
df.shape     # shape
# Out:
# (207, 41)

# %%
df.columns      # To print names of columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Country of Origin', 'Farm Name', 'Lot Number',
#        'Mill', 'ICO Number', 'Company', 'Altitude', 'Region', 'Producer',
#        'Number of Bags', 'Bag Weight', 'In-Country Partner', 'Harvest Year',
#        'Grading Date', 'Owner', 'Variety', 'Status', 'Processing Method',
#        'Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance',
#        'Uniformity', 'Clean Cup', 'Sweetness', 'Overall', 'Defects',
#        'Total Cup Points', 'Moisture Percentage', 'Category One Defects',
#        'Quakers', 'Color', 'Category Two Defects', 'Expiration',
#        'Certification Body', 'Certification Address', 'Certification Contact'],
#       dtype='object')

# %%
df.Altitude.value_counts()
# Out:
# 1200           23
# 1600           12
# 1300            7
# 1250            7
# 1400            7
#                ..
# 1411            1
# 4895 A 5650     1
# 400-600         1
# 200-400         1
# 850-1100        1
# Name: Altitude, Length: 97, dtype: int64

# %%
#Print summary statistics
df.describe()
# Out:
#        Unnamed: 0          ID  Number of Bags       Aroma      Flavor  \
# count  207.000000  207.000000      207.000000  207.000000  207.000000
# mean   103.000000  103.000000      155.449275    7.721063    7.744734
# std     59.899917   59.899917      244.484868    0.287626    0.279613
# min      0.000000    0.000000        1.000000    6.500000    6.750000
# 25%     51.500000   51.500000        1.000000    7.580000    7.580000
# 50%    103.000000  103.000000       14.000000    7.670000    7.750000
# 75%    154.500000  154.500000      275.000000    7.920000    7.920000
# max    206.000000  206.000000     2240.000000    8.580000    8.500000
#
#        Aftertaste    Acidity        Body     Balance  Uniformity  Clean Cup  \
# count  207.000000  207.00000  207.000000  207.000000  207.000000      207.0
# mean     7.599758    7.69029    7.640918    7.644058    9.990338       10.0
# std      0.275911    0.25951    0.233499    0.256299    0.103306        0.0
# ...

# %% [markdown]
# ## Interpret
# ### Aroma:
#   * Maximum value: 8.58
#   * Minimum value: 6.5
#   * Average value: 7.72
#
# ### Flavor:
#   * Maximum value: 8.5
#   * Minimum value: 6.75
#   * Avergae value: 7.75
#
# ### Aftertaste:
#   * Maximum value: 8.42
#   * Minimum value: 6.67
#   * Average value: 7.6
#
# ### Sweatness:
#   * Maximum value: 10
#   * Minimum value: 10
#   * Average value: 10
#
# ### Uniformity
#   * Maximum value: 10
#   * Minimum value: 6.67
#   * Average value: 9.9

# %% [markdown]
# ## Theorem
# ### Solve missing
# * Ostrict theorem - remove the whole row if a data is missing from it. (Not recommended)
# * Mean imputation - if any values are missing we take mean of all the values and fill the missing values with the mean values. (Used on field with loose requirements for accurate data. ie. not used in sensitive data example for medical practices)

# %%
# Inspect missing value in dataset
print(df.isnull().values.sum())
# Out:
# 153

# %%
print(df.isnull())
# Out:
#      Unnamed: 0     ID  Country of Origin  Farm Name  Lot Number   Mill  \
# 0         False  False              False      False       False  False
# 1         False  False              False      False       False  False
# 2         False  False              False      False       False  False
# 3         False  False              False      False       False  False
# 4         False  False              False      False       False  False
# ..          ...    ...                ...        ...         ...    ...
# 202       False  False              False      False       False  False
# 203       False  False              False      False       False  False
# 204       False  False              False      False       False  False
# 205       False  False              False      False       False  False
# 206       False  False              False      False       False  False
#
#      ICO Number  Company  Altitude  Region  ...  Total Cup Points  \
# ...

# %%
# Replace the ' 's with NaN
df = df.replace(" ",np.NaN)     # If there is missing values

# %%
# Impute the missing values with mean imputation
df = df.fillna(df.mean())       # Mean Theorem
# Out:
# /var/folders/xg/jzvt2kb51wxbb31l61yj09k00000gn/T/ipykernel_1022/3333199653.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(df.mean())       # Mean Theorem

# %%
# Count the number of NaNs in the dataset to verify
print(df.isnull().values.sum())
# Out:
# 153

# %%
# Inspect missing value in dataset
print(df.isnull().values.sum())
# Out:
# 153

# %%
# Since the missing values in not numerical value we are going to replace the value with a constant 0.
df = df.fillna(0)

# %%
# To confirm 
print(df.isnull().values.sum())    # Now all the missing values are replaced with 0
# Out:
# 0

# %%
# You can also check form info. All the missing numbers are now filled.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             207 non-null    int64
#  1   ID                     207 non-null    int64
#  2   Country of Origin      207 non-null    object
#  3   Farm Name              207 non-null    object
#  4   Lot Number             207 non-null    object
#  5   Mill                   207 non-null    object
#  6   ICO Number             207 non-null    object
#  7   Company                207 non-null    object
#  8   Altitude               207 non-null    object
#  9   Region                 207 non-null    object
#  10  Producer               207 non-null    object
#  11  Number of Bags         207 non-null    int64
#  12  Bag Weight             207 non-null    object
#  13  In-Country Partner     207 non-null    object
# ...

# %% [markdown]
# ### Since we can observe that the data now contains no missing values we are finally good to go for EDA Cycle.

# %% [markdown]
# # EDA Cycle

# %% [markdown]
# ## Count of Harvested Year

# %%
print(df["Harvest Year"].value_counts())
# Out:
# 2021 / 2022    99
# 2022           48
# 2022 / 2023    42
# 2021           13
# 2023            3
# 2017 / 2018     1
# 2018 / 2019     1
# Name: Harvest Year, dtype: int64

# %% [markdown]
# ## Pie Chart

# %%
country_counts = df['Country of Origin'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(10, 8))
plt.pie(country_counts, labels = country_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Coffee Samples by Country of Origin')
plt.show()

# %% [markdown]
# Interpretation
# * It is apparent that Taiwan has most of the coffee samples in the dataset being 31.2% followed by 9.6% of Colombia and 8.9%, 8.3%, 5.1% of Guatemala, Honduras, Costa Rica respectively.

# %% [markdown]
# ## Histogram

# %%
# Checking the data type as Histogram excepts either integer and float
print(df['Flavor'].dtype)
print(df['Altitude'].dtype)
# Out:
# float64
# object

# %%
# Since Altitude seems to have object we will need to convert it.


# Convert 'Altitude' to a float data type, handling non-numeric values
df['Altitude'] = pd.to_numeric(df['Altitude'], errors='coerce')  # 'coerce' converts non-numeric values to NaN
# Convert 'Flavor' to a float data type
df['Flavor'] = pd.to_numeric(df['Flavor'], errors='coerce')

# %%
# Checking the data type as Histogram excepts either integer and float
print(df['Flavor'].dtype)
print(df['Altitude'].dtype)
# Out:
# float64
# float64

# %%
sns.histplot(df['Flavor'], bins = 12, color = 'lightgreen', kde = False, edgecolor = 'green')


# Add labels
plt.title('Flavor')
plt.xlabel('Flavor')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# * The above Hisplot shows the flavor.
# * It is slightly left skewed.

# %%
# With kde
sns.histplot(df['Flavor'], bins = 10, color = 'lightgreen', kde = True, edgecolor = 'green')


# Add labels
plt.title('Flavor')
plt.xlabel('Flavor')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
sns.histplot(df['Altitude'], bins = 12, color = 'lightgreen', kde = True, edgecolor = 'green')

# Add labels
plt.title('Altitude in meter')
plt.xlabel('Altitude')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# * The above histplot represents variation in altitude.
# * The above histpolt is right skewed.

# %%
plt.figure(figsize=(14, 7))

# Subplot for the distribution of Aroma
plt.subplot(2, 2, 1)
sns.histplot(df['Aroma'], bins=20, kde=True)
plt.title('Distribution of Aroma Scores')

# Subplot for the distribution of Flavor
plt.subplot(2, 2, 2)
sns.histplot(df['Flavor'], bins=20, kde=True)
plt.title('Distribution of Flavor Scores')  

# Subplot for the distribution of Acidity
plt.subplot(2, 2, 3)
sns.histplot(df['Acidity'], bins=20, kde=True)
plt.title('Distribution of Acidity Scores')  

# Subplot for the distribution of Body
plt.subplot(2, 2, 4)
sns.histplot(df['Body'], bins=20, kde=True)
plt.title('Distribution of Body Scores')
# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatterplot

# %%
# Checking the data type as scatterplot excepts either integer and float
print(df['Flavor'].dtype)
print(df['Altitude'].dtype)
# Out:
# float64
# float64

# %%
# Since Altitude seems to have object we will need to convert it.

# Convert 'Altitude' to a float data type, handling non-numeric values
df['Altitude'] = pd.to_numeric(df['Altitude'], errors='coerce')  # 'coerce' converts non-numeric values to NaN

# %%
# Checking the data type as scatterplot excepts either integer and float
print(df['Flavor'].dtype)
print(df['Altitude'].dtype)
# Out:
# float64
# float64

# %%
# Seaborn Scatterplot     - mostly used if we have numerical values on both x and y and want to see the relation between them
sns.scatterplot(x=df['Flavor'], y=df['Altitude'])  # hue shows U- urban and R-rural


# Optionally, add labels and title
plt.title('Scatterplot of Flavor and Altitude')    # Overwrites already shown output in matplotlib. 
plt.xlabel('Flavor')                                 # Shows without these as well. And they both work on same engine.
plt.ylabel('Altitude')                             # Engine - seaborn --- accessed by sns.

#Show the plot           matplotlib covered one.
plt.show()

# %% [markdown]
# Intepretation
# * The above Scatterplot represents the relation between flavor and altitude.
# * There are some outliers in the dataset.
# * The coffee found in 5800 is an outliner in this data. Meaning it does go along or in the intepretated way.

# %%
# Scatterplot with hue 
sns.scatterplot(x=df['Flavor'], y=df['Altitude'], hue =df['Country of Origin'])  # hue displays the country of origin

# Move the legend outside the plot area so it does no obstruct the view.
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') 
plt.title('Scatterplot of Flavor and Altitude')     
plt.xlabel('Flavor')                                
plt.ylabel('Altitude')                           

plt.show()

# %% [markdown]
# Intepretation
# * Same as above scatterpolt but with countries indicate with the help of hue.
# * From the above scatterplot it is clear that the data set has more data from some countires like Colombia, Taiwan, Laos have more data.

# %% [markdown]
# ## Line plot

# %%
# line plot 
sns.lineplot(x='Flavor',y='Altitude', data=df )
# Out:
# <AxesSubplot: xlabel='Flavor', ylabel='Altitude'>

# %% [markdown]
# Interpret
# * The above figure is line pot between age and absences.
# * Blue shade showing confidence interval
# * If some values does not fall in the line it will have high probability of falling in the blue shaded region.

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize=(10,7))  # Adjust the figure width
sns.boxplot(x=df['Flavor'], y=df['Altitude'])

plt.xlabel ('Flavor')
plt.ylabel('Altitude')
plt.title('Boxplot')
plt.show()

# %% [markdown]
# Box plot gives five number summary of dataset which includes:
#    * the minimum value
#    * the first quartile(the 25th percentile)
#    * the medial value
#    * the third quartile(the 75th percentile)
#    * thee maximum value
#
# When comparing two or more box plot the main point to compare are:
# * Median value
# * Dispersion (min max values)
# * skewness
# * outlier

# %% [markdown]
# Interpret
# * The above boxplot shows flavor vs Altitude
# * There is a outliers are in 5800 altitude in 7.5 flavor range.
# * The distribution ranges form 100m altitude  to 2400m.

# %% [markdown]
# ## Heat Map

# %%
corrmat = df.corr()   # corr- function - gives the core relation  --- takes in matrix form
f, ax = plt.subplots(figsize = (16,12))   #plt is matplot - subplots is as its name suggests.
sns.heatmap(corrmat, vmax =.8, square = True)
# Out:
# /var/folders/xg/jzvt2kb51wxbb31l61yj09k00000gn/T/ipykernel_1022/2100064140.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()   # corr- function - gives the core relation  --- takes in matrix form
# <AxesSubplot: >

# %%
# Heat map with numerical representation.

plt.figure(figsize=(20,20))

colormap = sns.diverging_palette(10, 220, as_cmap = True)  # diverse range of color
sns.heatmap(df.corr(),                                     # .corr gives co-relation.
            cmap = colormap,
            square = True,
            annot = True,
            linewidths=0.1,vmax=1.0, linecolor='white',
            annot_kws={'fontsize':12 })
plt.show()
# Out:
# /var/folders/xg/jzvt2kb51wxbb31l61yj09k00000gn/T/ipykernel_1022/1166266009.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),                                     # .corr gives co-relation.

# %% [markdown]
# Interpretation
# * The red coloured and values such as -0.23, -0.50 are negatively related and values such as 0.50, 1 are positively related ie more interconnected with each other.
# * In this case altitude and flavor are positively related but does not affect each other highly.

# %% [markdown]
# ## Conclusion:
# * Taiwan has highest number of coffee sample in the data set.
# * Although the relation between altitude and flavor is weak positive it is enough to draw some conclusions.
#
# #### Best flavor
# * It is seen that most flavorful coffee beans are found at altitude of 1000-1800m. If a coffee production company tires to set of their production factories in these altitude there is high chances of the coffee beans being of good quality and flavorful.
# #### Backed up by:
# * This is also backed by the fact that most of the flavourful coffee are found at the  2,000-6,500 feet which converts to 1000 -1800 meter from the sea level.
